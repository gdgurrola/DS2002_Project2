# %% [markdown]
# ## Project 2: Capstone
#
# ### Section I: Prerequisites
#
# #### 1.0. Import Required Libraries

# %%
import os
import json
import pymongo
import pyspark.pandas as pd  # This uses Koalas that is included in PySpark version 3.2 or newer.
from pyspark.sql.functions import col
from pyspark.sql.types import StructType, StructField, StringType, TimestampType, BinaryType
from pyspark.sql.types import ByteType, ShortType, IntegerType, LongType, FloatType, DecimalType

# %% [markdown]
# #### 2.0. Instantiate Global Variables

# %%
# Azure MySQL Server Connection Information ###################
jdbc_hostname = "gex7ys-mysql.mysql.database.azure.com"
jdbc_port = 3306
src_database = "classicmodels_dw"

connection_properties = {
  "user" : "gdgurrola",
  "password" : "Kareldotmove22!",
  "driver" : "org.mariadb.jdbc.Driver"
}

# MongoDB Atlas Connection Information ########################
atlas_cluster_name = "ds2002cluster.kbzllxx" #"cluster_name.xxxxx"
atlas_database_name = "classicmodels_dw"
atlas_user_name = "gex7ys"
atlas_password = "Kareldotmove22!"

# Data Files (JSON) Information ###############################
dst_database = "classicmodels_dlh"

base_dir = "dbfs:/FileStore/lab_data"
database_dir = f"{base_dir}/{dst_database}"

data_dir = f"{base_dir}/retail"
batch_dir = f"{data_dir}/batch "
stream_dir = f"{data_dir}/stream"

orders_stream_dir = f"{stream_dir}/orders"
purchase_orders_stream_dir = f"{stream_dir}/purchase_orders"
inventory_trans_stream_dir = f"{stream_dir}/inventory_transactions"

orders_output_bronze = f"{database_dir}/fact_orders/bronze"
orders_output_silver = f"{database_dir}/fact_orders/silver"
orders_output_gold   = f"{database_dir}/fact_orders/gold"

# Delete the Streaming Files ################################## 
dbutils.fs.rm(f"{database_dir}/fact_orders", True) 

# Delete the Database Files ###################################
dbutils.fs.rm(database_dir, True)
# Out:
# True

# %% [markdown]
# #### 3.0. Define Global Functions

# %%
##################################################################################################################
# Use this Function to Fetch a DataFrame from the MongoDB Atlas database server Using PyMongo.
##################################################################################################################
def get_mongo_dataframe(user_id, pwd, cluster_name, db_name, collection, conditions, projection, sort):
    '''Create a client connection to MongoDB'''
    mongo_uri = f"mongodb+srv://{user_id}:{pwd}@{cluster_name}.mongodb.net/{db_name}"
    
    client = pymongo.MongoClient(mongo_uri)

    '''Query MongoDB, and fill a python list with documents to create a DataFrame'''
    db = client[db_name]
    if conditions and projection and sort:
        dframe = pd.DataFrame(list(db[collection].find(conditions, projection).sort(sort)))
    elif conditions and projection and not sort:
        dframe = pd.DataFrame(list(db[collection].find(conditions, projection)))
    else:
        dframe = pd.DataFrame(list(db[collection].find()))

    client.close()
    
    return dframe

##################################################################################################################
# Use this Function to Create New Collections by Uploading JSON file(s) to the MongoDB Atlas server.
##################################################################################################################
def set_mongo_collection(user_id, pwd, cluster_name, db_name, src_file_path, json_files):
    '''Create a client connection to MongoDB'''
    mongo_uri = f"mongodb+srv://{user_id}:{pwd}@{cluster_name}.mongodb.net/{db_name}"
    client = pymongo.MongoClient(mongo_uri)
    db = client[db_name]
    
    '''Read in a JSON file, and Use It to Create a New Collection'''
    for file in json_files:
        db.drop_collection(file)
        json_file = os.path.join(src_file_path, json_files[file])
        with open(json_file, 'r') as openfile:
            json_object = json.load(openfile)
            file = db[file]
            result = file.insert_many(json_object)

    client.close()
    
    return result

# %% [markdown]
# ### Section II: Populate Dimensions by Ingesting Reference (Cold-path) Data
# #### 1.0. Fetch Reference Data From an Azure MySQL Database
# ##### 1.1. Create a New Databricks Metadata Database.

# %%
# %sql
DROP DATABASE IF EXISTS classicmodels_dlh CASCADE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE DATABASE IF NOT EXISTS classicmodels_dlh
COMMENT "DS-2002 Project 2 Database"
LOCATION "dbfs:/FileStore/lab_data/classicmodels_dlh"
WITH DBPROPERTIES (contains_pii = true, purpose = "DS-2002 Project 2");
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ##### 1.2. Create a New Table that Sources Date Dimension Data from a Table in an Azure MySQL database.

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW view_date
USING org.apache.spark.sql.jdbc
OPTIONS (
  url "jdbc:mysql://gex7ys-mysql.mysql.database.azure.com:3306/classicmodels_dw", --Replace with your Server Name
  dbtable "dim_date",
  user "gdgurrola",    --Replace with your User Name
  password "Kareldotmove22!"  --Replace with you password
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
USE DATABASE classicmodels_dlh;

CREATE OR REPLACE TABLE classicmodels_dlh.dim_date
COMMENT "Date Dimension Table"
LOCATION "dbfs:/FileStore/lab_data/classicmodels_dlh/dim_date"
AS SELECT * FROM view_date
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE EXTENDED classicmodels_dlh.dim_date;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>date_key</td><td>int</td><td>null</td></tr><tr><td>full_date</td><td>date</td><td>null</td></tr><tr><td>date_name</td><td>varchar(11)</td><td>null</td></tr><tr><td>date_name_us</td><td>varchar(11)</td><td>null</td></tr><tr><td>date_name_eu</td><td>varchar(11)</td><td>null</td></tr><tr><td>day_of_week</td><td>int</td><td>null</td></tr><tr><td>day_name_of_week</td><td>varchar(10)</td><td>null</td></tr><tr><td>day_of_month</td><td>int</td><td>null</td></tr><tr><td>day_of_year</td><td>int</td><td>null</td></tr><tr><td>weekday_weekend</td><td>varchar(10)</td><td>null</td></tr><tr><td>week_of_year</td><td>int</td><td>null</td></tr><tr><td>month_name</td><td>varchar(10)</td><td>null</td></tr><tr><td>month_of_year</td><td>int</td><td>null</td></tr><tr><td>is_last_day_of_month</td><td>varchar(1)</td><td>null</td></tr><tr><td>calendar_quarter</td><td>int</td><td>null</td></tr><tr><td>calendar_year</td><td>int</td><td>null</td></tr><tr><td>calendar_year_month</td><td>varchar(10)</td><td>null</td></tr><tr><td>calendar_year_qtr</td><td>varchar(10)</td><td>null</td></tr><tr><td>fiscal_month_of_year</td><td>int</td><td>null</td></tr><tr><td>fiscal_quarter</td><td>int</td><td>null</td></tr><tr><td>fiscal_year</td><td>int</td><td>null</td></tr><tr><td>fiscal_year_month</td><td>varchar(10)</td><td>null</td></tr><tr><td>fiscal_year_qtr</td><td>varchar(10)</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>month_of_year, weekday_weekend, date_name_us, day_of_week, date_key, calendar_quarter, calendar_year_month, date_name_eu, date_name, fiscal_quarter, is_last_day_of_month, day_of_month, month_name, calendar_year_qtr, fiscal_year_qtr, full_date, fiscal_year_month, fiscal_month_of_year, calendar_year, day_name_of_week, day_of_year, week_of_year, fiscal_year</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>classicmodels_dlh</td><td></td></tr><tr><td>Table</td><td>dim_date</td><td></td></tr><tr><td>Created Time</td><td>Sun May 05 04:16:20 UTC 2024</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.4.1</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Comment</td><td>Date Dimension Table</td><td></td></tr><tr><td>Location</td><td>dbfs:/FileStore/lab_data/classicmodels_dlh/dim_date</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM classicmodels_dlh.dim_date LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date_key</th><th>full_date</th><th>date_name</th><th>date_name_us</th><th>date_name_eu</th><th>day_of_week</th><th>day_name_of_week</th><th>day_of_month</th><th>day_of_year</th><th>weekday_weekend</th><th>week_of_year</th><th>month_name</th><th>month_of_year</th><th>is_last_day_of_month</th><th>calendar_quarter</th><th>calendar_year</th><th>calendar_year_month</th><th>calendar_year_qtr</th><th>fiscal_month_of_year</th><th>fiscal_quarter</th><th>fiscal_year</th><th>fiscal_year_month</th><th>fiscal_year_qtr</th></tr></thead><tbody><tr><td>20000101</td><td>2000-01-01</td><td>2000/01/01</td><td>01/01/2000</td><td>01/01/2000</td><td>7</td><td>Saturday</td><td>1</td><td>1</td><td>Weekend</td><td>52</td><td>January</td><td>1</td><td>N</td><td>1</td><td>2000</td><td>2000-01</td><td>2000Q1</td><td>7</td><td>3</td><td>2000</td><td>2000-07</td><td>2000Q3</td></tr><tr><td>20000102</td><td>2000-01-02</td><td>2000/01/02</td><td>01/02/2000</td><td>02/01/2000</td><td>1</td><td>Sunday</td><td>2</td><td>2</td><td>Weekend</td><td>52</td><td>January</td><td>1</td><td>N</td><td>1</td><td>2000</td><td>2000-01</td><td>2000Q1</td><td>7</td><td>3</td><td>2000</td><td>2000-07</td><td>2000Q3</td></tr><tr><td>20000103</td><td>2000-01-03</td><td>2000/01/03</td><td>01/03/2000</td><td>03/01/2000</td><td>2</td><td>Monday</td><td>3</td><td>3</td><td>Weekday</td><td>1</td><td>January</td><td>1</td><td>N</td><td>1</td><td>2000</td><td>2000-01</td><td>2000Q1</td><td>7</td><td>3</td><td>2000</td><td>2000-07</td><td>2000Q3</td></tr><tr><td>20000104</td><td>2000-01-04</td><td>2000/01/04</td><td>01/04/2000</td><td>04/01/2000</td><td>3</td><td>Tuesday</td><td>4</td><td>4</td><td>Weekday</td><td>1</td><td>January</td><td>1</td><td>N</td><td>1</td><td>2000</td><td>2000-01</td><td>2000Q1</td><td>7</td><td>3</td><td>2000</td><td>2000-07</td><td>2000Q3</td></tr><tr><td>20000105</td><td>2000-01-05</td><td>2000/01/05</td><td>01/05/2000</td><td>05/01/2000</td><td>4</td><td>Wednesday</td><td>5</td><td>5</td><td>Weekday</td><td>1</td><td>January</td><td>1</td><td>N</td><td>1</td><td>2000</td><td>2000-01</td><td>2000Q1</td><td>7</td><td>3</td><td>2000</td><td>2000-07</td><td>2000Q3</td></tr></tbody></table></div>

# %% [markdown]
# ##### 1.3. Create a New Table that Sources Product Dimension Data from an Azure MySQL database.

# %%
# %sql

CREATE OR REPLACE TEMPORARY VIEW view_customer
USING org.apache.spark.sql.jdbc
OPTIONS (
  url "jdbc:mysql://gex7ys-mysql.mysql.database.azure.com:3306/classicmodels_dw", --Replace with your Server Name
  dbtable "dim_customers",
  user "gdgurrola",    --Replace with your User Name
  password "Kareldotmove22!"  --Replace with you password
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
USE DATABASE classicmodels_dlh;

CREATE OR REPLACE TABLE classicmodels_dlh.dim_customer
COMMENT "Customer Dimension Table"
LOCATION "dbfs:/FileStore/lab_data/classicmodels_dlh/dim_customer"
AS SELECT * FROM view_customer
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE EXTENDED classicmodels_dlh.dim_customer;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>customer_key</td><td>bigint</td><td>null</td></tr><tr><td>customerNumber</td><td>bigint</td><td>null</td></tr><tr><td>customerName</td><td>varchar(65535)</td><td>null</td></tr><tr><td>contactLastName</td><td>varchar(65535)</td><td>null</td></tr><tr><td>contactFirstName</td><td>varchar(65535)</td><td>null</td></tr><tr><td>addressLine1</td><td>varchar(65535)</td><td>null</td></tr><tr><td>city</td><td>varchar(65535)</td><td>null</td></tr><tr><td>postalCode</td><td>varchar(65535)</td><td>null</td></tr><tr><td>country</td><td>varchar(65535)</td><td>null</td></tr><tr><td>salesRepEmployeeNumber</td><td>double</td><td>null</td></tr><tr><td>creditLimit</td><td>double</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>addressLine1, city, contactFirstName, salesRepEmployeeNumber, customerName, creditLimit, country, postalCode, customerNumber, contactLastName, customer_key</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>classicmodels_dlh</td><td></td></tr><tr><td>Table</td><td>dim_customer</td><td></td></tr><tr><td>Created Time</td><td>Sun May 05 04:16:27 UTC 2024</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.4.1</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Comment</td><td>Customer Dimension Table</td><td></td></tr><tr><td>Location</td><td>dbfs:/FileStore/lab_data/classicmodels_dlh/dim_customer</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM classicmodels_dlh.dim_customer LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_key</th><th>customerNumber</th><th>customerName</th><th>contactLastName</th><th>contactFirstName</th><th>addressLine1</th><th>city</th><th>postalCode</th><th>country</th><th>salesRepEmployeeNumber</th><th>creditLimit</th></tr></thead><tbody><tr><td>1</td><td>103</td><td>Atelier graphique</td><td>Schmitt</td><td>Carine </td><td>54, rue Royale</td><td>Nantes</td><td>44000</td><td>France</td><td>1370.0</td><td>21000.0</td></tr><tr><td>2</td><td>112</td><td>Signal Gift Stores</td><td>King</td><td>Jean</td><td>8489 Strong St.</td><td>Las Vegas</td><td>83030</td><td>USA</td><td>1166.0</td><td>71800.0</td></tr><tr><td>3</td><td>114</td><td>Australian Collectors, Co.</td><td>Ferguson</td><td>Peter</td><td>636 St Kilda Road</td><td>Melbourne</td><td>3004</td><td>Australia</td><td>1611.0</td><td>117300.0</td></tr><tr><td>4</td><td>119</td><td>La Rochelle Gifts</td><td>Labrune</td><td>Janine </td><td>67, rue des Cinquante Otages</td><td>Nantes</td><td>44000</td><td>France</td><td>1370.0</td><td>118200.0</td></tr><tr><td>5</td><td>121</td><td>Baane Mini Imports</td><td>Bergulfsen</td><td>Jonas </td><td>Erling Skakkes gate 78</td><td>Stavern</td><td>4110</td><td>Norway</td><td>1504.0</td><td>81700.0</td></tr></tbody></table></div>

# %% [markdown]
# #### 2.0. Fetch Reference Data from a MongoDB Atlas Database
# ##### 2.1. View the Data Files on the Databricks File System

# %%
display(dbutils.fs.ls("dbfs:/FileStore/lab_data/retail/batch"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/lab_data/retail/batch/classicmodels_employees.json</td><td>classicmodels_employees.json</td><td>5206</td><td>1714874565000</td></tr><tr><td>dbfs:/FileStore/lab_data/retail/batch/classicmodels_orders.json</td><td>classicmodels_orders.json</td><td>70595</td><td>1714874565000</td></tr><tr><td>dbfs:/FileStore/lab_data/retail/batch/classicmodels_payments.csv</td><td>classicmodels_payments.csv</td><td>8994</td><td>1714874565000</td></tr><tr><td>dbfs:/FileStore/lab_data/retail/batch/classicmodels_payments.json</td><td>classicmodels_payments.json</td><td>8994</td><td>1714874565000</td></tr></tbody></table></div>

# %% [markdown]
# ##### 2.2. Create a New MongoDB Database, and Load JSON Data Into a New MongoDB Collection
# **NOTE:** The following cell **can** be run more than once because the **set_mongo_collection()** function **is** idempotent.

# %%
source_dir = "/dbfs/FileStore/lab_data/retail/batch"
json_files = {"employees" : 'classicmodels_employees.json'
              , "orders" : 'classicmodels_orders.json'}

set_mongo_collection(atlas_user_name, atlas_password, atlas_cluster_name, atlas_database_name, source_dir, json_files)

# %% [markdown]
# ##### 2.3.1. Fetch Customer Dimension Data from the New MongoDB Collection

# %%
# %scala
import com.mongodb.spark._

val userName = "gex7ys"
val pwd = "Kareldotmove22!"
val clusterName = "ds2002cluster.kbzllxx"
val atlas_uri = s"mongodb+srv://$userName:$pwd@$clusterName.mongodb.net/?retryWrites=true&w=majority"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">import com.mongodb.spark._
# userName: String = gex7ys
# pwd: String = Kareldotmove22!
# clusterName: String = ds2002cluster.kbzllxx
# atlas_uri: String = mongodb+srv://gex7ys:Kareldotmove22!@ds2002cluster.kbzllxx.mongodb.net/?retryWrites=true&amp;w=majority
# </div>

# %%
# %scala

val df_employee = spark.read.format("com.mongodb.spark.sql.DefaultSource")
.option("database", "classicmodels_dw")
.option("collection", "employees")
.option("uri", atlas_uri).load()
.select("employeeNumber","lastName","firstName","jobTitle","extension", "email" ,"reportsTo" )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">df_employee: org.apache.spark.sql.DataFrame = [employeeNumber: int, lastName: string ... 5 more fields]
# </div>

# %%
# %scala
df_employee.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- employeeNumber: integer (nullable = true)
# -- lastName: string (nullable = true)
# -- firstName: string (nullable = true)
# -- jobTitle: string (nullable = true)
# -- extension: string (nullable = true)
# -- email: string (nullable = true)
# -- reportsTo: integer (nullable = true)
#
# </div>

# %%
# %scala
df_employee.write.format("delta").mode("overwrite").saveAsTable("classicmodels_dlh.dim_employee")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
DESCRIBE EXTENDED classicmodels_dlh.dim_employee
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>employeeNumber</td><td>int</td><td>null</td></tr><tr><td>lastName</td><td>string</td><td>null</td></tr><tr><td>firstName</td><td>string</td><td>null</td></tr><tr><td>jobTitle</td><td>string</td><td>null</td></tr><tr><td>extension</td><td>string</td><td>null</td></tr><tr><td>email</td><td>string</td><td>null</td></tr><tr><td>reportsTo</td><td>int</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>email, reportsTo, lastName, firstName, employeeNumber, jobTitle, extension</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>classicmodels_dlh</td><td></td></tr><tr><td>Table</td><td>dim_employee</td><td></td></tr><tr><td>Created Time</td><td>Sun May 05 04:16:41 UTC 2024</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.4.1</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td>dbfs:/FileStore/lab_data/classicmodels_dlh/dim_employee</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM classicmodels_dlh.dim_employee LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employeeNumber</th><th>lastName</th><th>firstName</th><th>jobTitle</th><th>extension</th><th>email</th><th>reportsTo</th></tr></thead><tbody><tr><td>1002</td><td>Murphy</td><td>Diane</td><td>President</td><td>x5800</td><td>dmurphy@classicmodelcars.com</td><td>null</td></tr><tr><td>1056</td><td>Patterson</td><td>Mary</td><td>VP Sales</td><td>x4611</td><td>mpatterso@classicmodelcars.com</td><td>1002</td></tr><tr><td>1076</td><td>Firrelli</td><td>Jeff</td><td>VP Marketing</td><td>x9273</td><td>jfirrelli@classicmodelcars.com</td><td>1002</td></tr><tr><td>1088</td><td>Patterson</td><td>William</td><td>Sales Manager (APAC)</td><td>x4871</td><td>wpatterson@classicmodelcars.com</td><td>1056</td></tr><tr><td>1102</td><td>Bondur</td><td>Gerard</td><td>Sale Manager (EMEA)</td><td>x5408</td><td>gbondur@classicmodelcars.com</td><td>1056</td></tr></tbody></table></div>

# %% [markdown]
# ##### 2.4.1 Fetch Supplier Dimension Data from the New MongoDB Collection

# %%
# %scala

val df_order = spark.read.format("com.mongodb.spark.sql.DefaultSource")
.option("database", "classicmodels_dw")
.option("collection", "orders")
.option("uri", atlas_uri).load()
.select("orderNumber","orderDate","requiredDate","shippedDate","status", "comments" ,"customerNumber" )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">df_order: org.apache.spark.sql.DataFrame = [orderNumber: int, orderDate: string ... 5 more fields]
# </div>

# %%
# %scala
df_order.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- orderNumber: integer (nullable = true)
# -- orderDate: string (nullable = true)
# -- requiredDate: string (nullable = true)
# -- shippedDate: string (nullable = true)
# -- status: string (nullable = true)
# -- comments: string (nullable = true)
# -- customerNumber: integer (nullable = true)
#
# </div>

# %%
# %scala
df_order.write.format("delta").mode("overwrite").saveAsTable("classicmodels_dlh.dim_orders")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
DESCRIBE EXTENDED classicmodels_dlh.dim
# %%
# %sql
DESCRIBE EXTENDED classicmodels_dlh.dim_payments;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>customerNumber</td><td>int</td><td>null</td></tr><tr><td>checkNumber</td><td>string</td><td>null</td></tr><tr><td>paymentDate</td><td>date</td><td>null</td></tr><tr><td>amount</td><td>double</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>customerNumber, checkNumber, paymentDate, amount</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>classicmodels_dlh</td><td></td></tr><tr><td>Table</td><td>dim_payments</td><td></td></tr><tr><td>Created Time</td><td>Sun May 05 04:17:01 UTC 2024</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.4.1</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td>dbfs:/FileStore/lab_data/classicmodels_dlh/dim_payments</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM classicmodels_dlh.dim_payments LIMIT 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customerNumber</th><th>checkNumber</th><th>paymentDate</th><th>amount</th></tr></thead><tbody><tr><td>103</td><td>HQ336336</td><td>2004-10-19</td><td>6066.78</td></tr><tr><td>103</td><td>JM555205</td><td>2003-06-05</td><td>14571.44</td></tr><tr><td>103</td><td>OM314933</td><td>2004-12-18</td><td>1676.14</td></tr><tr><td>112</td><td>BO864823</td><td>2004-12-17</td><td>14191.12</td></tr><tr><td>112</td><td>HQ55022</td><td>2003-06-06</td><td>32641.98</td></tr></tbody></table></div>

# %% [markdown]
# ##### Verify Dimension Tables

# %%
# %sql
USE classicmodels_dlh;
SHOW TABLES
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>classicmodels_dlh</td><td>dim_customer</td><td>false</td></tr><tr><td>classicmodels_dlh</td><td>dim_date</td><td>false</td></tr><tr><td>classicmodels_dlh</td><td>dim_employee</td><td>false</td></tr><tr><td>classicmodels_dlh</td><td>dim_orders</td><td>false</td></tr><tr><td>classicmodels_dlh</td><td>dim_payments</td><td>false</td></tr><tr><td></td><td>display_query_1</td><td>true</td></tr><tr><td></td><td>display_query_2</td><td>true</td></tr><tr><td></td><td>fact_orders</td><td>true</td></tr><tr><td></td><td>fact_orders_silver_tempview</td><td>true</td></tr><tr><td></td><td>orders_bronze_tempview</td><td>true</td></tr><tr><td></td><td>orders_raw_tempview</td><td>true</td></tr><tr><td></td><td>orders_silver_tempview</td><td>true</td></tr><tr><td></td><td>view_customer</td><td>true</td></tr><tr><td></td><td>view_date</td><td>true</td></tr></tbody></table></div>

# %% [markdown]
# ### Section III: Integrate Reference Data with Real-Time Data
# #### 6.0. Use AutoLoader to Process Streaming (Hot Path) Orders Fact Data
# ##### 6.1. Bronze Table: Process 'Raw' JSON Data

# %%
(spark.readStream
 .format("cloudFiles")
 .option("cloudFiles.format", "json")
 .option("cloudFiles.schemaLocation", orders_output_bronze)
 .option("cloudFiles.inferColumnTypes", "true")
 .option("multiLine", "true")
 .load(orders_stream_dir)
 .createOrReplaceTempView("orders_raw_tempview"))

# %%
# %sql
/* Add Metadata for Traceability */
CREATE OR REPLACE TEMPORARY VIEW orders_bronze_tempview AS (
  SELECT *, current_timestamp() receipt_time, input_file_name() source_file
  FROM orders_raw_tempview
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT * FROM orders_bronze_tempview
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>comments</th><th>customerNumber</th><th>orderDate</th><th>orderNumber</th><th>requiredDate</th><th>shippedDate</th><th>status</th><th>_rescued_data</th><th>receipt_time</th><th>source_file</th></tr></thead><tbody><tr><td>null</td><td>363</td><td>2003-01-06</td><td>10100</td><td>2003-01-13</td><td>2003-01-10</td><td>Shipped</td><td>null</td><td>2024-05-05T04:17:23.33Z</td><td>dbfs:/FileStore/lab_data/retail/stream/orders/classicmodels_orders.json</td></tr><tr><td>Check on availability.</td><td>128</td><td>2003-01-09</td><td>10101</td><td>2003-01-18</td><td>2003-01-11</td><td>Shipped</td><td>null</td><td>2024-05-05T04:17:23.33Z</td><td>dbfs:/FileStore/lab_data/retail/stream/orders/classicmodels_orders.json</td></tr><tr><td>null</td><td>181</td><td>2003-01-10</td><td>10102</td><td>2003-01-18</td><td>2003-01-14</td><td>Shipped</td><td>null</td><td>2024-05-05T04:17:23.33Z</td><td>dbfs:/FileStore/lab_data/retail/stream/orders/classicmodels_orders.json</td></tr><tr><td>null</td><td>121</td><td>2003-01-29</td><td>10103</td><td>2003-02-07</td><td>2003-02-02</td><td>Shipped</td><td>null</td><td>2024-05-05T04:17:23.33Z</td><td>dbfs:/FileStore/lab_data/retail/stream/orders/classicmodels_orders.json</td></tr><tr><td>null</td><td>141</td><td>2003-01-31</td><td>10104</td><td>2003-02-09</td><td>2003-02-01</td><td>Shipped</td><td>null</td><td>2024-05-05T04:17:23.33Z</td><td>dbfs:/FileStore/lab_data/retail/stream/orders/classicmodels_orders.json</td></tr><tr><td>null</td><td>145</td><td>2003-02-11</td><td>10105</td><td>2003-02-21</td><td>2003-02-12</td><td>Shipped</td><td>null</td><td>2024-05-05T04:17:23.33Z</td><td>dbfs:/FileStore/lab_data/retail/stream/orders/classicmodels_orders.json</td></tr><tr><td>null</td><td>278</td><td>2003-02-17</td><td>10106</td><td>2003-02-24</td><td>2003-02-21</td><td>Shipped</td><td>null</td><td>2024-05-05T04:17:23.33Z</td><td>dbfs:/FileStore/lab_data/retail/stream/orders/classicmodels_orders.json</td></tr><tr><td>
td><td>string</td><td>null</td></tr><tr><td>status</td><td>string</td><td>null</td></tr><tr><td>_rescued_data</td><td>string</td><td>null</td></tr><tr><td>receipt_time</td><td>timestamp</td><td>null</td></tr><tr><td>source_file</td><td>string</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW fact_orders_silver_tempview AS (
  SELECT 
    o.orderNumber AS order_id,
    o.customerNumber AS customer_id,
    c.customer_key,
    c.customerName AS customer_name,
    c.contactLastName AS contact_last_name,
    c.contactFirstName AS contact_first_name,
    c.addressLine1 AS customer_address,
    c.city AS customer_city,
    c.postalCode AS customer_postal_code,
    c.country AS customer_country,
    c.salesRepEmployeeNumber AS sales_rep_id,
    e.employeeNumber AS employee_id,
    e.lastName AS employee_last_name,
    e.firstName AS employee_first_name,
    e.jobTitle AS employee_job_title,
    o.comments,
    o.orderDate,
    o.requiredDate,
    o.shippedDate,
    o.status,
    o._rescued_data,
    o.receipt_time,
    o.source_file
  FROM orders_silver_tempview o
  INNER JOIN dim_customer c ON o.customerNumber = c.customerNumber
  LEFT JOIN dim_employee e ON c.salesRepEmployeeNumber = e.employeeNumber
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
(spark.table("fact_orders_silver_tempview")
      .writeStream
      .format("delta")
      .option("checkpointLocation", f"{orders_output_silver}/_checkpoint")
      .outputMode("append")
      .table("fact_orders_silver"))

# %%
# %sql
SELECT * FROM fact_orders_silver
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_id</th><th>customer_key</th><th>customer_name</th><th>contact_last_name</th><th>contact_first_name</th><th>customer_address</th><th>customer_city</th><th>customer_postal_code</th><th>customer_country</th><th>sales_rep_id</th><th>employee_id</th><th>employee_last_name</th><th>employee_first_name</th><th>employee_job_title</th><th>comments</th><th>orderDate</th><th>requiredDate</th><th>shippedDate</th><th>status</th><th>_rescued_data</th><th>receipt_time</th><th>source_file</th></tr></thead><tbody><tr><td>10345</td><td>103</td><td>1</td><td>Atelier graphique</td><td>Schmitt</td><td>Carine </td><td>54, rue Royale</td><td>Nantes</td><td>44000</td><td>France</td><td>1370.0</td><td>1370</td><td>Hernandez</td><td>Gerard</td><td>Sales Rep</td><td>null</td><td>2004-11-25</td><td>2004-12-01</td><td>2004-11-26</td><td>Shipped</td><td>null</td><td>2024-05-05T04:17:32.605Z</td><td>dbfs:/FileStore/lab_data/retail/stream/orders/classicmodels_orders.json</td></tr><tr><td>10346</td><td>112</td><td>2</td><td>Signal Gift Stores</td><td>King</td><td>Jean</td><td>8489 Strong St.</td><td>Las Vegas</td><td>83030</td><td>USA</td><td>1166.0</td><td>1166</td><td>Thompson</td><td>Leslie</td><td>Sales Rep</td><td>null</td><td>2004-11-29</td><td>2004-12-05</td><td>2004-11-30</td><td>Shipped</td><td>null</td><td>2024-05-05T04:17:32.605Z</td><td>dbfs:/FileStore/lab_data/retail/stream/orders/classicmodels_orders.json</td></tr><tr><td>10347</td><td>114</td><td>3</td><td>Australian Collectors, Co.</td><td>Ferguson</td><td>Peter</td><td>636 St Kilda Road</td><td>Melbourne</td><td>3004</td><td>Australia</td><td>1611.0</td><td>1611</td><td>Fixter</td><td>Andy</td><td>Sales Rep</td><td>Can we deliver the new Ford Mustang models by end-of-quarter?</td><td>2004-11-29</td><td>2004-12-07</td><td>2004-11-30</td><td>Shipped</td><td>null</td><td>2024-05-05T04:17:32.605Z</td><td>dbfs:/FileStore/lab_data/retail/stream/orders/classicmodels_orders.json</td></tr><tr><td>10425</td><td>119</td><td>4</td><td>La Rochelle Gifts</td><td>Labrune</td><td>Janine </td><td>67, rue des Cinquante Otages</td><td>Nantes</td><td>44000</td><td>France</td><td>1370.0</td><td>1370</td><td>Hernandez</td><td>Gerard</td><td>Sales Rep</td><td>null</td><td>2005-05-31</td><td>2005-06-07</td><td>null</td><td>In Process</td><td>null</td><td>2024-05-05T04:17:32.605Z</td><td>dbfs:/FileStore/lab_data/retail/stream/orders/classicmodels_orders.json</td></tr><tr><td>10325</td><td>121</td><td>5</td><td>Baane Mini Imports</td><td>Bergulfsen</td><td>Jonas </td><td>Erling Skakkes gate 78</td><td>Stavern</td><td>4110</td><td>Norway</td><td>1504.0</td><td>1504</td><td>Jones</td><td>Barry</td><td>Sales Rep</td><td>null</td><td>2004-11-05</td><td>2004-11-13</td><td>2004-11-08</td><td>Shipped</td><td>null</td><td>2024-05-05T04:17:32.605Z</td><td>dbfs:/FileStore/lab_data/retail/stream/orders/classicmodels_orders.json</td></tr><tr><td>10421</td><td>124</td><td>6</td><td>Mini Gifts Distributors Ltd.</td><td>Nelson</td><td>Susan</td><td>5677 Strong St.</td><td>San Rafael</td><td>97562</td><td>USA</td><td>1165.0</td><td>1165</td><td>Jennings</td><td>Leslie</td><td>Sales Rep</td><td>Custom shipping instructions were sent to warehouse</td><td>2005-05-29</td><td>2005-06-06</td><td>null</td><td>In Process</td><td>null</td><td>2024-05-05T04:17:32.605Z</td><td>dbfs:/FileStore/lab_data/retail/stream/orders/classicmodels_orders.json</td></tr><tr><td>10323</td><td>128</td><td>8</td><td>Blauer See Auto, Co.</td><td>Keitel</td><td>Roland</td><td>Lyonerstr. 34</td><td>Frankfurt</td><td>60528</td><td>Germany</td><td>1504.0</td><td>1504</td><td>Jones</td><td>Barry</td><td>Sales Rep</td><td>null</td><td>2004-11-05</td><td>2004-11-12</td><td>2004-11-09</td><td>Shipped</td><td>null</td><td>2024-05-05T04:17:32.605Z</td><td>dbfs:/FileStore/lab_data/retail/stream/orders/classicmodels_orders.json</td> ...

# %%
# %sql
DESCRIBE EXTENDED classicmodels_dlh.fact_orders_silver
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>order_id</td><td>bigint</td><td>null</td></tr><tr><td>customer_id</td><td>bigint</td><td>null</td></tr><tr><td>customer_key</td><td>bigint</td><td>null</td></tr><tr><td>customer_name</td><td>varchar(65535)</td><td>null</td></tr><tr><td>contact_last_name</td><td>varchar(65535)</td><td>null</td></tr><tr><td>contact_first_name</td><td>varchar(65535)</td><td>null</td></tr><tr><td>customer_address</td><td>varchar(65535)</td><td>null</td></tr><tr><td>customer_city</td><td>varchar(65535)</td><td>null</td></tr><tr><td>customer_postal_code</td><td>varchar(65535)</td><td>null</td></tr><tr><td>customer_country</td><td>varchar(65535)</td><td>null</td></tr><tr><td>sales_rep_id</td><td>double</td><td>null</td></tr><tr><td>employee_id</td><td>int</td><td>null</td></tr><tr><td>employee_last_name</td><td>string</td><td>null</td></tr><tr><td>employee_first_name</td><td>string</td><td>null</td></tr><tr><td>employee_job_title</td><td>string</td><td>null</td></tr><tr><td>comments</td><td>string</td><td>null</td></tr><tr><td>orderDate</td><td>string</td><td>null</td></tr><tr><td>requiredDate</td><td>string</td><td>null</td></tr><tr><td>shippedDate</td><td>string</td><td>null</td></tr><tr><td>status</td><td>string</td><td>null</td></tr><tr><td>_rescued_data</td><td>string</td><td>null</td></tr><tr><td>receipt_time</td><td>timestamp</td><td>null</td></tr><tr><td>source_file</td><td>string</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>employee_id, employee_last_name, receipt_time, order_id, customer_id, customer_name, customer_postal_code, orderDate, customer_address, contact_last_name, employee_first_name, contact_first_name, customer_country, sales_rep_id, status, customer_city, _rescued_data, employee_job_title, shippedDate, requiredDate, customer_key, comments, source_file</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>classicmodels_dlh</td><td></td></tr><tr><td>Table</td><td>fact_orders_silver</td><td></td></tr><tr><td>Created Time</td><td>Sun May 05 04:17:53 UTC 2024</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.4.1</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td>dbfs:/FileStore/lab_data/classicmodels_dlh/fact_orders_silver</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %% [markdown]
# ##### 6.3. Gold Table: Perform Aggregations
# Create a new Gold table using the CTAS approach.

# %%
# %sql
CREATE OR REPLACE TABLE classicmodels_dlh.fact_monthly_orders_by_customer_gold AS (
  SELECT 
    employee_last_name AS LastName,
    employee_first_name AS FirstName,
    employee_job_title AS JobTitle,
    COUNT(order_id) AS totalOrdersHandled
  FROM classicmodels_dlh.fact_orders_silver
  WHERE employee_job_title = 'Sales Rep'
  GROUP BY LastName, FirstName, employee_job_title -- Including employee_job_title in GROUP BY
  ORDER BY TotalOrdersHandled DESC
);

SELECT * FROM classicmodels_dlh.fact_monthly_orders_by_customer_gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LastName</th><th>FirstName</th><th>JobTitle</th><th>totalOrdersHandled</th></tr></thead><tbody><tr><td>Hernandez</td><td>Gerard</td><td>Sales Rep</td><td>43</td></tr><tr><td>Jennings</td><td>Leslie</td><td>Sales Rep</td><td>34</td></tr><tr><td>Castillo</td><td>Pamela</td><td>Sales Rep</td><td>31</td></tr><tr><td>Jones</td><td>Barry</td><td>Sales Rep</td><td>25</td></tr><tr><td>Bott</td><td>Larry</td><td>Sales Rep</td><td>22</td></tr><tr><td>Vanauf</td><td>George</td><td>Sales Rep</td><td>22</td></tr><tr><td>Bondur</td><td>Loui</td><td>Sales Rep</td><td>20</td></tr><tr><td>Fixter</td><td>Andy</td><td>Sales Rep</td><td>19</td></tr><tr><td>Marsh</td><td>Peter</td><td>Sales Rep</td><td>19</td></tr><tr><td>Patterson</td><td>Steve</td><td>Sales Rep</td><td>18</td></tr><tr><td>Tseng</td><td>Foon Yue</td><td>Sales Rep</td><td>17</td></tr><tr><td>Nishi</td><td>Mami</td><td>Sales Rep</td><td>16</td></tr><tr><td>Firrelli</td><td>Julie</td><td>Sales Rep</td><td>14</td></tr><tr><td>Thompson</td><td>Leslie</td><td>Sales Rep</td><td>14</td></tr><tr><td>Gerard</td><td>Martin</td><td>Sales Rep</td><td>12</td></tr></tbody></table></div>
